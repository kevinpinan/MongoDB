# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

client = MongoClient('mongodb+srv://kevinpinan:maggy1234@cluster0.bqoij.mongodb.net/test')
#db.create_collection("clasemongodb")
db = client["clasemongodb"]

listas= db.listas

import numpy as np
import random

print("LISTADO DE CIUDADANOS")
nombres=["Luis","Miguel","Kevin","Dustin","Paula","Steven","Paul","Jorge","Ricardo","Eduardo"]
apellidos=["Muzo","Chavez","Pinanjota","Perez","Zambrano","Zaldumbide","Guaniuna","Espinoza","Escobar","Monteros"]


k=int(input("INGRESE N CIUDADANOS"))

for i in range(k):
    a = np.random.randint(low=1, high=1000000009, size=1).tolist()
    
    edad = np.random.randint(low=18, high=80, size=1).tolist()

    

    nom_C=[]
    ape_C=[]
    
    
    for i in range (2):
        n=np.random.randint(0,9)
        nom_C.append(nombres[n])

    print(nom_C)
    
    


    for i in range (2):
        n=np.random.randint(0,9)
        ape_C.append(apellidos[n])
        
    print(ape_C)
    print(edad)
    
    p=a[0]*9
    print(p)

    
    print("--------------------------------------------------------------------------------")
    
    
    script=[{'Nombres_Completos':nom_C,'Apellidos_Completos':ape_C,'Edad:':edad,'Cedula:':p}]
    
    listas.insert_many(script)
    
    print("****************************")
print("Crear una función que muestre los elementos ingresados en la base de datos.")
cursor = db.listas.find({})
for doc in cursor:
    print(doc)
# Out:
# LISTADO DE CIUDADANOS
# INGRESE N CIUDADANOS10
# ['Steven', 'Paula']
# ['Muzo', 'Zaldumbide']
# [65]
# 6590267199
# --------------------------------------------------------------------------------
# ****************************
# ['Paula', 'Paula']
# ['Zambrano', 'Chavez']
# [53]
# 2331835920
# --------------------------------------------------------------------------------
# ****************************
# ['Steven', 'Paul']
# ['Perez', 'Pinanjota']
# [28]
# 2071462761
# --------------------------------------------------------------------------------
# ****************************
# ['Paula', 'Paul']
# ['Pinanjota', 'Chavez']
# [51]
# 489862188
# --------------------------------------------------------------------------------
# ****************************
# ['Paula', 'Steven']
# ['Pinanjota', 'Zambrano']
# [73]
# 3438109566
# --------------------------------------------------------------------------------
# ****************************
# ['Dustin', 'Kevin']
# ['Pinanjota', 'Pinanjota']
# [26]
# 3409957989
# --------------------------------------------------------------------------------
# ****************************
# ['Dustin', 'Miguel']
# ['Chavez', 'Chavez']
# [34]
# 4254349248
# --------------------------------------------------------------------------------
# ****************************
# ['Paul', 'Paul']
# ['Espinoza', 'Espinoza']
# [36]
# 1434743010
# --------------------------------------------------------------------------------
# ****************************
# ['Ricardo', 'Jorge']
# ['Guaniuna', 'Zambrano']
# [23]
# 3968023869
# --------------------------------------------------------------------------------
# ****************************
# ['Paul', 'Kevin']
# ['Espinoza', 'Pinanjota']
# [34]
# 8410357287
# --------------------------------------------------------------------------------
# ****************************
# Crear una función que muestre los elementos ingresados en la base de datos.
# {'_id': ObjectId('61e8b2e1f26822fe6b7bcd2f'), 'Nombres_Completos': ['Paula', 'Kevin'], 'Apellidos_Completos': ['Escobar', 'Guaniuna'], 'Edad:': [64], 'Cedula:': 3848413509}
# {'_id': ObjectId('61e8b2e2f26822fe6b7bcd30'), 'Nombres_Completos': ['Luis', 'Dustin'], 'Apellidos_Completos': ['Zaldumbide', 'Chavez'], 'Edad:': [69], 'Cedula:': 1249861599}
# {'_id': ObjectId('61e8b2e2f26822fe6b7bcd31'), 'Nombres_Completos': ['Ricardo', 'Luis'], 'Apellidos_Completos': ['Espinoza', 'Chavez'], 'Edad:': [59], 'Cedula:': 8847096237}
# {'_id': ObjectId('61e8b2e2f26822fe6b7bcd32'), 'Nombres_Completos': ['Paul', 'Paul'], 'Apellidos_Completos': ['Escobar', 'Zambrano'], 'Edad:': [32], 'Cedula:': 1339912989}
# {'_id': ObjectId('61e8b2e2f26822fe6b7bcd33'), 'Nombres_Completos': ['Dustin', 'Luis'], 'Apellidos_Completos': ['Espinoza', 'Espinoza'], 'Edad:': [30], 'Cedula:': 4302754650}
# {'_id': ObjectId('61e8b2e3f26822fe6b7bcd34'), 'Nombres_Completos': ['Kevin', 'Paula'], 'Apellidos_Completos': ['Zambrano', 'Escobar'], 'Edad:': [60], 'Cedula:': 4034174931}
# {'_id': ObjectId('61e8b2e3f26822fe6b7bcd35'), 'Nombres_Completos': ['Dustin', 'Dustin'], 'Apellidos_Completos': ['Escobar', 'Espinoza'], 'Edad:': [72], 'Cedula:': 132798942}
# {'_id': ObjectId('61e8b2e3f26822fe6b7bcd36'), 'Nombres_Completos': ['Kevin', 'Jorge'], 'Apellidos_Completos': ['Guaniuna', 'Zaldumbide'], 'Edad:': [46], 'Cedula:': 8056810971}
# {'_id': ObjectId('61e8b2e3f26822fe6b7bcd37'), 'Nombres_Completos': ['Kevin', 'Steven'], 'Apellidos_Completos': ['Muzo', 'Zambrano'], 'Edad:': [51], 'Cedula:': 1013817951}
# {'_id': ObjectId('61e8b2e3f26822fe6b7bcd38'), 'Nombres_Completos': ['Dustin', 'Paul'], 'Apellidos_Completos': ['Pinanjota', 'Escobar'], 'Edad:': [72], 'Cedula:': 6948383760}
# {'_id': ObjectId('61e8c5f8f26822fe6b7bcd3a'), 'Nombres_Completos': ['Steven', 'Paula'], 'Apellidos_Completos': ['Muzo', 'Zaldumbide'], 'Edad:': [65], 'Cedula:': 6590267199}
# {'_id': ObjectId('61e8c5f9f26822fe6b7bcd3b'), 'Nombres_Completos': ['Paula', 'Paula'], 'Apellidos_Completos': ['Zambrano', 'Chavez'], 'Edad:': [53], 'Cedula:': 2331835920}
# {'_id': ObjectId('61e8c5f9f26822fe6b7bcd3c'), 'Nombres_Completos': ['Steven', 'Paul'], 'Apellidos_Completos': ['Perez', 'Pinanjota'], 'Edad:': [28], 'Cedula:': 2071462761}
# {'_id': ObjectId('61e8c5f9f26822fe6b7bcd3d'), 'Nombres_Completos': ['Paula', 'Paul'], 'Apellidos_Completos': ['Pinanjota', 'Chavez'], 'Edad:': [51], 'Cedula:': 489862188}
# {'_id': ObjectId('61e8c5f9f26822fe6b7bcd3e'), 'Nombres_Completos': ['Paula', 'Steven'], 'Apellidos_Completos': ['Pinanjota', 'Zambrano'], 'Edad:': [73], 'Cedula:': 3438109566}
# {'_id': ObjectId('61e8c5faf26822fe6b7bcd3f'), 'Nombres_Completos': ['Dustin', 'Kevin'], 'Apellidos_Completos': ['Pinanjota', 'Pinanjota'], 'Edad:': [26], 'Cedula:': 3409957989}
# {'_id': ObjectId('61e8c5faf26822fe6b7bcd40'), 'Nombres_Completos': ['Dustin', 'Miguel'], 'Apellidos_Completos': ['Chavez', 'Chavez'], 'Edad:': [34], 'Cedula:': 4254349248}
# {'_id': ObjectId('61e8c5faf26822fe6b7bcd41'), 'Nombres_Completos': ['Paul', 'Paul'], 'Apellidos_Completos': ['Espinoza', 'Espinoza'], 'Edad:': [36], 'Cedula:': 1434743010}
# {'_id': ObjectId('61e8c5faf26822fe6b7bcd42'), 'Nombres_Completos': ['Ricardo', 'Jorge'], 'Apellidos_Completos': ['Guaniuna', 'Zambrano'], 'Edad:': [23], 'Cedula:': 3968023869}
# {'_id': ObjectId('61e8c5faf26822fe6b7bcd43'), 'Nombres_Completos': ['Paul', 'Kevin'], 'Apellidos_Completos': ['Espinoza', 'Pinanjota'], 'Edad:': [34], 'Cedula:': 8410357287}
